# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# %%
x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

# %%
qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
qual_lo = fuzz.trimf(x_serv, [0, 0, 5])
qual_md = fuzz.trimf(x_serv, [0, 5, 10])
qual_hi = fuzz.trimf(x_serv, [5, 10, 10])
qual_lo = fuzz.trimf(x_tip, [0, 0, 13])
qual_md = fuzz.trimf(x_tip, [0, 13, 25])
qual_hi = fuzz.trimf(x_tip, [13, 25, 25])

# %%
fig, (ax0, ax1, ax2) = plt.subplots(nrow=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, qual_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, qual_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, qual_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(false)
    ax.spines['right'].set_visible(false)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4546d641cc57> in <module>
# ----> 1 fig, (ax0, ax1, ax2) = plt.subplots(nrow=3, figsize=(8,9))
#       2
#       3 ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
#       4 ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
#       5 ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     538             dpi = 72
#     539
# --> 540         figManager = new_figure_manager(num, figsize=figsize,
#     541                                         dpi=dpi,
#     542                                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3355         from matplotlib.figure import Figure
#    3356         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3357         fig = fig_cls(*args, **kwargs)
#    3358         return cls.new_figure_manager_given_figure(num, fig)
#    3359
#
# TypeError: __init__() got an unexpected keyword argument 'nrow'

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
serv_lo = fuzz.trimf(x_serv, [0, 0, 5])
serv_md = fuzz.trimf(x_serv, [0, 5, 10])
serv_hi = fuzz.trimf(x_serv, [5, 10, 10])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

fig, (ax0, ax1, ax2) = plt.subplots(row=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_qual, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_qual, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_qual, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(false)
    ax.spines['right'].set_visible(false)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9396d18f8160> in <module>
#      17 tip_hi = fuzz.trimf(x_tip, [13, 25, 25])
#      18
# ---> 19 fig, (ax0, ax1, ax2) = plt.subplots(nrow=3, figsize=(8,9))
#      20
#      21 ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     538             dpi = 72
#     539
# --> 540         figManager = new_figure_manager(num, figsize=figsize,
#     541                                         dpi=dpi,
#     542                                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3355         from matplotlib.figure import Figure
#    3356         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3357         fig = fig_cls(*args, **kwargs)
#    3358         return cls.new_figure_manager_given_figure(num, fig)
#    3359
#
# TypeError: __init__() got an unexpected keyword argument 'nrow'

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
serv_lo = fuzz.trimf(x_serv, [0, 0, 5])
serv_md = fuzz.trimf(x_serv, [0, 5, 10])
serv_hi = fuzz.trimf(x_serv, [5, 10, 10])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

fig, (ax0, ax1, ax2) = plt.subplots(row=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_qual, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_qual, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_qual, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(false)
    ax.spines['right'].set_visible(false)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-4cb6c87975cd> in <module>
#      17 tip_hi = fuzz.trimf(x_tip, [13, 25, 25])
#      18
# ---> 19 fig, (ax0, ax1, ax2) = plt.subplots(row=3, figsize=(8,9))
#      20
#      21 ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     538             dpi = 72
#     539
# --> 540         figManager = new_figure_manager(num, figsize=figsize,
#     541                                         dpi=dpi,
#     542                                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3355         from matplotlib.figure import Figure
#    3356         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3357         fig = fig_cls(*args, **kwargs)
#    3358         return cls.new_figure_manager_given_figure(num, fig)
#    3359
#
# TypeError: __init__() got an unexpected keyword argument 'row'

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
serv_lo = fuzz.trimf(x_serv, [0, 0, 5])
serv_md = fuzz.trimf(x_serv, [0, 5, 10])
serv_hi = fuzz.trimf(x_serv, [5, 10, 10])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

fig, (ax0, ax1, ax2) = plt.subplots(row=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_qual, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_qual, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_qual, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(false)
    ax.spines['right'].set_visible(false)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4cb6c87975cd> in <module>
#      17 tip_hi = fuzz.trimf(x_tip, [13, 25, 25])
#      18
# ---> 19 fig, (ax0, ax1, ax2) = plt.subplots(row=3, figsize=(8,9))
#      20
#      21 ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     538             dpi = 72
#     539
# --> 540         figManager = new_figure_manager(num, figsize=figsize,
#     541                                         dpi=dpi,
#     542                                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3355         from matplotlib.figure import Figure
#    3356         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3357         fig = fig_cls(*args, **kwargs)
#    3358         return cls.new_figure_manager_given_figure(num, fig)
#    3359
#
# TypeError: __init__() got an unexpected keyword argument 'row'

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
serv_lo = fuzz.trimf(x_serv, [0, 0, 5])
serv_md = fuzz.trimf(x_serv, [0, 5, 10])
serv_hi = fuzz.trimf(x_serv, [5, 10, 10])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

fig, (ax0, ax1, ax2) = plt.subplots(nrow=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_qual, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_qual, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_qual, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(false)
    ax.spines['right'].set_visible(false)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9396d18f8160> in <module>
#      17 tip_hi = fuzz.trimf(x_tip, [13, 25, 25])
#      18
# ---> 19 fig, (ax0, ax1, ax2) = plt.subplots(nrow=3, figsize=(8,9))
#      20
#      21 ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     538             dpi = 72
#     539
# --> 540         figManager = new_figure_manager(num, figsize=figsize,
#     541                                         dpi=dpi,
#     542                                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3355         from matplotlib.figure import Figure
#    3356         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3357         fig = fig_cls(*args, **kwargs)
#    3358         return cls.new_figure_manager_given_figure(num, fig)
#    3359
#
# TypeError: __init__() got an unexpected keyword argument 'nrow'

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
serv_lo = fuzz.trimf(x_serv, [0, 0, 5])
serv_md = fuzz.trimf(x_serv, [0, 5, 10])
serv_hi = fuzz.trimf(x_serv, [5, 10, 10])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_tip, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_tip, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_tip, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(false)
    ax.spines['right'].set_visible(false)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c82a986e48eb> in <module>
#      31 ax1.legend()
#      32
# ---> 33 ax2.plot(x_qual, tip_lo, 'b', linewidth=1.5, label='Low')
#      34 ax2.plot(x_qual, tip_md, 'g', linewidth=1.5, label='Medium')
#      35 ax2.plot(x_qual, tip_hi, 'r', linewidth=1.5, label='High')
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (11,) and (26,)

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
serv_lo = fuzz.trimf(x_serv, [0, 0, 5])
serv_md = fuzz.trimf(x_serv, [0, 5, 10])
serv_hi = fuzz.trimf(x_serv, [5, 10, 10])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_tip, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_tip, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_tip, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(false)
    ax.spines['right'].set_visible(false)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-035678bab775> in <module>
#      39 # Turn off top/right axes
#      40 for ax in(ax0, ax1, ax2):
# ---> 41     ax.spines['top'].set_visible(false)
#      42     ax.spines['right'].set_visible(false)
#      43     ax.get_xaxis().tick_bottom()
#
# NameError: name 'false' is not defined

# %%
qual_level_lo = fuzz.interp_membership(x_qual, [6.5])
qual_level_md = fuzz.interp_membership(x_qual, [6.5])
qual_level_hi = fuzz.interp_membership(x_qual, [6.5])

serv_level_lo = fuzz.interp_membership(x_serv, [9.8])
serv_level_md = fuzz.interp_membership(x_serv, [9.8])
serv_level_hi = fuzz.interp_membership(x_serv, [9.8])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-edd07bfc34cf> in <module>
# ----> 1 qual_level_lo = fuzz.interp_membership(x_qual, [6.5])
#       2 qual_level_md = fuzz.interp_membership(x_qual, [6.5])
#       3 qual_level_hi = fuzz.interp_membership(x_qual, [6.5])
#       4
#       5 serv_level_lo = fuzz.interp_membership(x_serv, [9.8])
#
# NameError: name 'fuzz' is not defined

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_level_lo = fuzz.interp_membership(x_qual, qual_lo, [6.5])
qual_level_md = fuzz.interp_membership(x_qual, qual_md, [6.5])
qual_level_hi = fuzz.interp_membership(x_qual, qual_hi[6.5])

serv_level_lo = fuzz.interp_membership(x_serv, serv_lo[9.8])
serv_level_md = fuzz.interp_membership(x_serv, serv_md[9.8])
serv_level_hi = fuzz.interp_membership(x_serv, serv_hi[9.8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a371a7574825> in <module>
#       7 x_tip = np.arange(0, 26, 1)
#       8
# ----> 9 qual_level_lo = fuzz.interp_membership(x_qual, [6.5])
#      10 qual_level_md = fuzz.interp_membership(x_qual, [6.5])
#      11 qual_level_hi = fuzz.interp_membership(x_qual, [6.5])
#
# TypeError: interp_membership() missing 1 required positional argument: 'xx'

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 5])
qual_md = fuzz.trimf(x_qual, [0, 5, 10])
qual_hi = fuzz.trimf(x_qual, [5, 10, 10])
serv_lo = fuzz.trimf(x_serv, [0, 0, 5])
serv_md = fuzz.trimf(x_serv, [0, 5, 10])
serv_hi = fuzz.trimf(x_serv, [5, 10, 10])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_tip, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_tip, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_tip, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97892a33dfed> in <module>
#      39 # Turn off top/right axes
#      40 for ax in(ax0, ax1, ax2):
# ---> 41     ax.spines['top'].set_visible(false)
#      42     ax.spines['right'].set_visible(false)
#      43     ax.get_xaxis().tick_bottom()
#
# NameError: name 'false' is not defined

# %%
qual_level_lo = fuzz.interp_membership(x_qual, qual_lo, [6.5])
qual_level_md = fuzz.interp_membership(x_qual, qual_md, [6.5])
qual_level_hi = fuzz.interp_membership(x_qual, qual_hi[6.5])

serv_level_lo = fuzz.interp_membership(x_serv, serv_lo[9.8])
serv_level_md = fuzz.interp_membership(x_serv, serv_md[9.8])
serv_level_hi = fuzz.interp_membership(x_serv, serv_hi[9.8])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-66e3e85157a9> in <module>
#       1 qual_level_lo = fuzz.interp_membership(x_qual, qual_lo, [6.5])
#       2 qual_level_md = fuzz.interp_membership(x_qual, qual_md, [6.5])
# ----> 3 qual_level_hi = fuzz.interp_membership(x_qual, qual_hi[6.5])
#       4
#       5 serv_level_lo = fuzz.interp_membership(x_serv, serv_lo[9.8])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
qual_level_lo = fuzz.interp_membership(x_qual, qual_lo, [6.5])
qual_level_md = fuzz.interp_membership(x_qual, qual_md, [6.5])
qual_level_hi = fuzz.interp_membership(x_qual, qual_hi, [6.5])

serv_level_lo = fuzz.interp_membership(x_serv, serv_lo, [9.8])
serv_level_md = fuzz.interp_membership(x_serv, serv_md, [9.8])
serv_level_hi = fuzz.interp_membership(x_serv, serv_hi, [9.8])

# %%
active_rule1 = np_fmax(qual_level_lo, serv_level_lo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b92eccc8d438> in <module>
# ----> 1 active_rule1 = np_fmax(qual_level_lo, serv_level_lo)
#
# NameError: name 'np_fmax' is not defined

# %%
active_rule1 = np_fmax(qual_level_lo, serv_level_lo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b92eccc8d438> in <module>
# ----> 1 active_rule1 = np_fmax(qual_level_lo, serv_level_lo)
#
# NameError: name 'np_fmax' is not defined

# %%
tip_activation_lo = np.fmin(active_rule1, tip_lo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b621ffb05512> in <module>
# ----> 1 tip_activation_lo = np.fmin(active_rule1, tip_lo)
#
# NameError: name 'active_rule1' is not defined

# %%
tip_activation_md = np.fmin(serv_level_md, tip_md)

# %%
active_rule3 = np.fmax(qual_level_hi, serv_level_hi)
tip_activation_hi = np.fmin(active_rule3, tip_hi)
tip0 = np.zeros_like(x_tip)

# %%
ax0.fill_between(x_tip, tip0, tip_activation_lo, facecolor='b', alpha = 0.7)
ax0.plot(x_tip, tip_lo, 'b', linewidth = 0.5,linestyle = '--',)
ax0.fill_between(x_tip, tip0, tip_activation_md, facecolor='g', alpha = 0.7)
ax0.plot(x_tip, tip_md, 'b', linewidth = 0.5,linestyle = '--')
ax0.fill_between(x_tip, tip0, tip_activation_hi, facecolor='r', alpha = 0.7)
ax0.plot(x_tip, tip_hi, 'b', linewidth = 0.5,linestyle = '--')
ax0.set_title('Output membership activity')

for ax in (ax0,);
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
plt.tight_layout()
# Out:
#   File "<ipython-input-9-139ab0e95e82>", line 9
#     for ax in (ax0,);
#                     ^
# SyntaxError: invalid syntax

# %%
ax0.fill_between(x_tip, tip0, tip_activation_lo, facecolor='b', alpha = 0.7)
ax0.plot(x_tip, tip_lo, 'b', linewidth = 0.5,linestyle = '--',)
ax0.fill_between(x_tip, tip0, tip_activation_md, facecolor='g', alpha = 0.7)
ax0.plot(x_tip, tip_md, 'g', linewidth = 0.5,linestyle = '--',)
ax0.fill_between(x_tip, tip0, tip_activation_hi, facecolor='r', alpha = 0.7)
ax0.plot(x_tip, tip_hi, 'r', linewidth = 0.5,linestyle = '--',)
ax0.set_title('Output membership activity')

for ax in (ax0,):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cecf83763028> in <module>
# ----> 1 ax0.fill_between(x_tip, tip0, tip_activation_lo, facecolor='b', alpha = 0.7)
#       2 ax0.plot(x_tip, tip_lo, 'b', linewidth = 0.5,linestyle = '--',)
#       3 ax0.fill_between(x_tip, tip0, tip_activation_md, facecolor='g', alpha = 0.7)
#       4 ax0.plot(x_tip, tip_md, 'b', linewidth = 0.5,linestyle = '--')
#       5 ax0.fill_between(x_tip, tip0, tip_activation_hi, facecolor='r', alpha = 0.7)
#
# NameError: name 'tip_activation_lo' is not defined

# %%
aggregated = np.fmax(tip_activationlo, np.fmax(tip_activation_md, tip_activation_hi))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-128294c9f43c> in <module>
# ----> 1 aggregated = np.fmax(tip_activationlo, np.fmax(tip_activation_md, tip_activation_hi))
#
# NameError: name 'tip_activationlo' is not defined

# %%
aggregated = np.fmax(tip_activation_lo, np.fmax(tip_activation_md, tip_activation_hi))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-cd8ee09c866e> in <module>
# ----> 1 aggregated = np.fmax(tip_activation_lo, np.fmax(tip_activation_md, tip_activation_hi))
#
# NameError: name 'tip_activation_lo' is not defined

# %%
tip = fuzz.defuzz(x_tip, aggregated,'som')
tip_activation = fuzz.interp_membership(x_tip,aggregated, tip)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b2584b52dab1> in <module>
# ----> 1 tip = fuzz.defuzz(x_tip, aggregated,'centroid')
#       2 tip_activation = fuzz.interp_membership(x_tip,aggregated, tip)
#
# NameError: name 'aggregated' is not defined

# %%
fig, ax0 = plt.subplots(figsize=(8,3))

ax0.plot(x_tip, tip_lo, 'b', linewidth=0.5, linestyle='--', )
ax0.plot(x_tip, tip_md, 'g', linewidth=0.5, linestyle='--', )
ax0.plot(x_tip, tip_hi, 'r', linewidth=0.5, linestyle='--', )
ax0.fill_between(x_tip, tip0, aggregated, facecolor='Orange', alpha = 0.7)
ax0.plot([tip,tip], [0,tip_activation], 'k', linewidth=1.5, alpha=0.9)
ax0.set_title('aggregated membership and result (line)')

for ax in (ax0,):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9c5f6991739d> in <module>
#       4 ax0.plot(x_tip, tip_md, 'g', linewidth=0.5, linestyle='--', )
#       5 ax0.plot(x_tip, tip_hi, 'r', linewidth=0.5, linestyle='--', )
# ----> 6 ax0.fill_between(x_tip, tip0, aggregated, facecolor='Orange', alpha = 0.7)
#       7 ax0.plot([tip,tip], [0,tip_activation], 'k', linewidth=1.5, alpha=0.9)
#       8 ax0.set_title('aggregated membership and result (line)')
#
# NameError: name 'aggregated' is not defined

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 7])
qual_md = fuzz.trimf(x_qual, [0, 7, 13])
qual_hi = fuzz.trimf(x_qual, [7, 7, 13])
serv_lo = fuzz.trimf(x_serv, [0, 0, 13])
serv_md = fuzz.trimf(x_serv, [0, 7, 13])
serv_hi = fuzz.trimf(x_serv, [7,13, 13])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])
# Out:
#   File "<ipython-input-1-1d2644b66beb>", line 14
#     serv_hi = fuzz.trimf(x_serv, [7,13 13])
#                                        ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
x_serv = np.arange(0, 11, 1)
x_tip = np.arange(0, 26, 1)

qual_lo = fuzz.trimf(x_qual, [0, 0, 7])
qual_md = fuzz.trimf(x_qual, [0, 7, 13])
qual_hi = fuzz.trimf(x_qual, [7, 7, 13])
serv_lo = fuzz.trimf(x_serv, [0, 0, 13])
serv_md = fuzz.trimf(x_serv, [0, 7, 13])
serv_hi = fuzz.trimf(x_serv, [7,13, 13])
tip_lo = fuzz.trimf(x_tip, [0, 0, 13])
tip_md = fuzz.trimf(x_tip, [0, 13, 25])
tip_hi = fuzz.trimf(x_tip, [13, 25, 25])

fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(8,9))

ax0.plot(x_qual, qual_lo, 'b', linewidth=1.5, label='Bad')
ax0.plot(x_qual, qual_md, 'g', linewidth=1.5, label='Decent')
ax0.plot(x_qual, qual_hi, 'r', linewidth=1.5, label='Great')
ax0.set_title('Food quality')
ax0.legend()

ax1.plot(x_serv, serv_lo, 'b', linewidth=1.5, label='Poor')
ax1.plot(x_serv, serv_md, 'g', linewidth=1.5, label='Acceptable')
ax1.plot(x_serv, serv_hi, 'r', linewidth=1.5, label='Amazing')
ax1.set_title('Service quality')
ax1.legend()

ax2.plot(x_tip, tip_lo, 'b', linewidth=1.5, label='Low')
ax2.plot(x_tip, tip_md, 'g', linewidth=1.5, label='Medium')
ax2.plot(x_tip, tip_hi, 'r', linewidth=1.5, label='High')
ax2.set_title('Tip Amount')
ax2.legend()

# Turn off top/right axes
for ax in(ax0, ax1, ax2):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
plt.tight_layout()

# %%
qual_level_lo = fuzz.interp_membership(x_qual, qual_lo, [6.5])
qual_level_md = fuzz.interp_membership(x_qual, qual_md, [6.5])
qual_level_hi = fuzz.interp_membership(x_qual, qual_hi, [6.5])

serv_level_lo = fuzz.interp_membership(x_serv, serv_lo, [9.8])
serv_level_md = fuzz.interp_membership(x_serv, serv_md, [9.8])
serv_level_hi = fuzz.interp_membership(x_serv, serv_hi, [9.8])

active_rule1 = np_fmax(qual_level_lo, serv_level_lo)
tip_activation_lo = np.fmin(active_rule1, tip_lo)
tip_activation_md = np.fmin(serv_level_md, tip_md)
active_rule3 = np.fmax(qual_level_hi, serv_level_hi)
tip_activation_hi = np.fmin(active_rule3, tip_hi)
tip0 = np.zeros_like(x_tip)

fig, ax0 = plt.subplots(figsize=(8,3))

ax0.fill_between(x_tip, tip0, tip_activation_lo, facecolor='b', alpha = 0.7)
ax0.plot(x_tip, tip_lo, 'b', linewidth = 0.5,linestyle = '--',)
ax0.fill_between(x_tip, tip0, tip_activation_md, facecolor='g', alpha = 0.7)
ax0.plot(x_tip, tip_md, 'g', linewidth = 0.5,linestyle = '--',)
ax0.fill_between(x_tip, tip0, tip_activation_hi, facecolor='r', alpha = 0.7)
ax0.plot(x_tip, tip_hi, 'r', linewidth = 0.5,linestyle = '--',)
ax0.set_title('Output membership activity')

for ax in (ax0,):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c32722b73279> in <module>
#       7 serv_level_hi = fuzz.interp_membership(x_serv, serv_hi, [9.8])
#       8
# ----> 9 active_rule1 = np_fmax(qual_level_lo, serv_level_lo)
#      10 tip_activation_lo = np.fmin(active_rule1, tip_lo)
#      11 tip_activation_md = np.fmin(serv_level_md, tip_md)
#
# NameError: name 'np_fmax' is not defined

# %%
aggregated = np.fmax(tip_activation_lo, 
                     np.fmax(tip_activation_md, tip_activation_hi))
tip = fuzz.defuzz(x_tip, aggregated,'som')
tip_activation = fuzz.interp_membership(x_tip,aggregated, tip)

fig, ax0 = plt.subplots(figsize=(8,3))

ax0.plot(x_tip, tip_lo, 'b', linewidth=0.5, linestyle='--', )
ax0.plot(x_tip, tip_md, 'g', linewidth=0.5, linestyle='--', )
ax0.plot(x_tip, tip_hi, 'r', linewidth=0.5, linestyle='--', )
ax0.fill_between(x_tip, tip0, aggregated, facecolor='Orange', alpha = 0.7)
ax0.plot([tip,tip], [0,tip_activation], 'k', linewidth=1.5, alpha=0.9)
ax0.set_title('aggregated membership and result (line)')

for ax in (ax0,):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-00da1e45e3ec> in <module>
# ----> 1 aggregated = np.fmax(tip_activation_lo, np.fmax(tip_activation_md, tip_activation_hi))
#       2 tip = fuzz.defuzz(x_tip, aggregated,'som')
#       3 tip_activation = fuzz.interp_membership(x_tip,aggregated, tip)
#       4
#       5 fig, ax0 = plt.subplots(figsize=(8,3))
#
# NameError: name 'tip_activation_lo' is not defined

# %%
aggregated = np.fmax(tip_activation_lo, 
                     np.fmax(tip_activation_md, tip_activation_hi))
tip = fuzz.defuzz(x_tip, aggregated,'som')
tip_activation = fuzz.interp_membership(x_tip,aggregated, tip)

fig, ax0 = plt.subplots(figsize=(8,3))

ax0.plot(x_tip, tip_lo, 'b', linewidth=0.5, linestyle='--', )
ax0.plot(x_tip, tip_md, 'g', linewidth=0.5, linestyle='--', )
ax0.plot(x_tip, tip_hi, 'r', linewidth=0.5, linestyle='--', )
ax0.fill_between(x_tip, tip0, aggregated, facecolor='Orange', alpha = 0.7)
ax0.plot([tip,tip], [0,tip_activation], 'k', linewidth=1.5, alpha=0.9)
ax0.set_title('aggregated membership and result (line)')

for ax in (ax0,):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-76f8479e97fa> in <module>
# ----> 1 aggregated = np.fmax(tip_activation_lo,
#       2                      np.fmax(tip_activation_md, tip_activation_hi))
#       3 tip = fuzz.defuzz(x_tip, aggregated,'som')
#       4 tip_activation = fuzz.interp_membership(x_tip,aggregated, tip)
#       5
#
# NameError: name 'tip_activation_lo' is not defined

# %%
fig, ax0 = plt.subplots(figsize=(8,3))

ax0.plot(x_tip, tip_lo, 'b', linewidth=0.5, linestyle='--', )
ax0.plot(x_tip, tip_md, 'g', linewidth=0.5, linestyle='--', )
ax0.plot(x_tip, tip_hi, 'r', linewidth=0.5, linestyle='--', )
ax0.fill_between(x_tip, tip0, aggregated, facecolor='Orange', alpha = 0.7)
ax0.plot([tip,tip], [0,tip_activation], 'k', linewidth=1.5, alpha=0.9)
ax0.set_title('aggregated membership and result (line)')

for ax in (ax0,):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9c5f6991739d> in <module>
#       4 ax0.plot(x_tip, tip_md, 'g', linewidth=0.5, linestyle='--', )
#       5 ax0.plot(x_tip, tip_hi, 'r', linewidth=0.5, linestyle='--', )
# ----> 6 ax0.fill_between(x_tip, tip0, aggregated, facecolor='Orange', alpha = 0.7)
#       7 ax0.plot([tip,tip], [0,tip_activation], 'k', linewidth=1.5, alpha=0.9)
#       8 ax0.set_title('aggregated membership and result (line)')
#
# NameError: name 'tip0' is not defined

# %%
fig, ax0 = plt.subplots(figsize=(8,3))

ax0.fill_between(x_tip, tip0, tip_activation_lo, facecolor='b', alpha = 0.7)
ax0.plot(x_tip, tip_lo, 'b', linewidth = 0.5,linestyle = '--',)
ax0.fill_between(x_tip, tip0, tip_activation_md, facecolor='g', alpha = 0.7)
ax0.plot(x_tip, tip_md, 'g', linewidth = 0.5,linestyle = '--',)
ax0.fill_between(x_tip, tip0, tip_activation_hi, facecolor='r', alpha = 0.7)
ax0.plot(x_tip, tip_hi, 'r', linewidth = 0.5,linestyle = '--',)
ax0.set_title('Output membership activity')

for ax in (ax0,):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e01fb6406064> in <module>
#       1 fig, ax0 = plt.subplots(figsize=(8,3))
#       2
# ----> 3 ax0.fill_between(x_tip, tip0, tip_activation_lo, facecolor='b', alpha = 0.7)
#       4 ax0.plot(x_tip, tip_lo, 'b', linewidth = 0.5,linestyle = '--',)
#       5 ax0.fill_between(x_tip, tip0, tip_activation_md, facecolor='g', alpha = 0.7)
#
# NameError: name 'tip0' is not defined
